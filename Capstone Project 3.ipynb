# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset Import

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\Capstone EDA.csv")

# %% [markdown]
# # Dataset Information

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges Churn  gender  ...  \
# 0           Electronic check           29.85         29.85    No  Female  ...
# 1               Mailed check           56.95       1889.50    No    Male  ...
# 2               Mailed check           53.85        108.15   Yes    Male  ...
# 3  Bank transfer (automatic)           42.30       1840.75    No    Male  ...
# 4           Electronic check           70.70        151.65   Yes  Female  ...
#
#    year month     MultipleLines  InternetService  OnlineSecurity  \
# ...

# %%
df.shape
# Out:
# (7043, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   float64
#  8   Churn             7043 non-null   object
#  9   gender            7043 non-null   object
#  10  SeniorCitizen     7043 non-null   int64
#  11  Partner           7043 non-null   object
#  12  Dependents        7043 non-null   object
#  13  Day               7043 non-null   int64
#  14  year              7043 non-null   int64
#  15  month             7043 non-null   int64
# ...

# %% [markdown]
# # Check Missing Values

# %%
df.isnull().sum()
# Out:
# customerID          0
# tenure              0
# PhoneService        0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Day                 0
# year                0
# month               0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %% [markdown]
# There are no missing values in the data

# %% [markdown]
# # Check Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no duplicate value

# %% [markdown]
# # Data Understanding

# %% [markdown]
# Statistical Analysis

# %%
#Seperate categorical and numerical data
Categorical = ["customerID","gender","Partner","Dependents","PhoneService","MultipleLines","InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies","Contract","PaperlessBilling","PaymentMethod","Churn"]
Numerical = ["SeniorCitizen","tenure","MonthlyCharges","TotalCharges"]

# %%
#Numerical data statistical Analysis
df[Numerical].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count         7043.0  7043.000000     7043.000000   7043.000000
# mean             0.0    32.371149       64.761692   2279.734304
# std              0.0    24.559481       30.090047   2266.794470
# min              0.0     0.000000       18.250000      0.000000
# 25%              0.0     9.000000       35.500000    398.550000
# 50%              0.0    29.000000       70.350000   1394.550000
# 75%              0.0    55.000000       89.850000   3786.600000
# max              0.0    72.000000      118.750000   8684.800000

# %% [raw]
# # 1.SeniorCitizen not present in the data.
# # 2.Tenure mean is greater than the median so the distribution tends to be positively skew.
# # 3.Monthly Charges mean smaller than the median so the distribution tends to be negetive skew.
# # 4.Total Charges mena is greater than the median so the distribution tends to be positive skew.

# %%
#Categorical data statistical Analysis
df[Categorical].describe().T
# Out:
#                  count unique               top  freq
# customerID        7043   7043        3186-AJIEK     1
# gender            7043      2              Male  3555
# Partner           7043      2                No  3641
# Dependents        7043      2                No  4933
# PhoneService      7043      2               Yes  6361
# MultipleLines     7043      3                No  3390
# InternetService   7043      3       Fiber optic  3096
# OnlineSecurity    7043      3                No  3498
# OnlineBackup      7043      3                No  3088
# DeviceProtection  7043      3                No  3095
# TechSupport       7043      3                No  3473
# StreamingTV       7043      3                No  2810
# StreamingMovies   7043      3                No  2785
# Contract          7043      3    Month-to-month  3875
# PaperlessBilling  7043      2               Yes  4171
# PaymentMethod     7043      4  Electronic check  2365
# ...

# %%
#See value from the Categorical data:
for col in Categorical:
    print(f"The value of {col} is")
    print(df[col].value_counts(), "\n")
# Out:
# The value of customerID is
# customerID
# 3186-AJIEK    1
# 7590-VHVEG    1
# 5575-GNVDE    1
# 8775-CEBBJ    1
# 2823-LKABH    1
#              ..
# 6713-OKOMC    1
# 1452-KIOVK    1
# 9305-CDSKC    1
# 9237-HQITU    1
# 7795-CFOCW    1
# Name: count, Length: 7043, dtype: int64
#
# The value of gender is
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
# The value of Partner is
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
# The value of Dependents is
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
# The value of PhoneService is
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
#
# The value of MultipleLines is
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# The value of InternetService is
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# Countplot Churn

# %%
plt.figure(figsize = (8,4))
ax = sns.countplot(x = df["Churn"], palette = {"Yes": "orange", "No": "blue"})
ax.bar_label(ax.containers[0], color = "black")
plt.title("Distribution Churn")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Countplot based on Customer Demographics

# %%
features = ["gender","Partner","Dependents"]
plt.figure(figsize = (18,6))
for i in range(0,len(features)):
    plt.subplot(1, len(features), i+1)
    ax = sns.countplot(x = df[features[i]], palette = {"Yes": "Orange", "No": "Blue", "Male": "Orange", "Female": "Blue"})
    ax.bar_label(ax.containers[0], color = "Black")
    plt.title("Distribution " + features[i])
    plt.ylabel("Number of Customers")
    plt.tight_layout()

# %% [raw]
# #1.It can be seen that customers based on gender and Partner tend to be balanced.
# #2.It can be seen in the Dependents column that as many as 70% of the majority of the customers do not have Dependents.

# %% [markdown]
# Countplot Based on Service Type

# %%
features = ["PhoneService","MultipleLines","InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies"]
plt.figure(figsize = (12,16))
for i in range(0,len(features)):
    plt.subplot(4, len(features)//3, i+1)
    ax = sns.countplot(x = df[features[i]], palette = {"Yes": "Orange", "No": "Blue", "No phone service": "red", "DSL": "Red", "Fiber optic": "Orange", "No Internet": "Red"})
    ax.bar_label(ax.containers[0], color = "Black")
    plt.title("Distribution " + features[i])
    plt.ylabel("Number of Customers")
    plt.tight_layout()

# %% [raw]
# #1.It can be seen that customes to have Phoneservice and the the majority do not have MultipleLines.
# #2.Most customer use Fiber optic InternetService.
# #3.For the OnlineSecurity,OnlineBackup,DeviceProtection,TechSupport columns the distribution is unbalanced and most of the customers do not have this services

# %% [markdown]
# Countplot based on Payment Type

# %%
features = ["Contract","PaperlessBilling","PaymentMethod"]
plt.figure(figsize = (12,6))
for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    ax = sns.countplot(x = df[features[i]], palette = {"Month-to-month": "Blue", "One year": "Orange", "Two year": "Green", "Yes": "Blue", "No": "Orange", "Electronic check": "Blue", "Mailed check": "Orange", "Bank transfer (automatic)": "Green", "Credit card (automatic)": "Red"})
    ax.bar_label(ax.containers[0], color = "Black")
    plt.title("Distribution " + features[i])
    plt.ylabel("Number of Customers")
    plt.xticks(rotation = 25)
    plt.tight_layout()

# %% [raw]
# #1.The distribution of payment contract is not balanced and most of customers made payments monthly.
# #2.The most of the customers use Paperless Bills.
# #3.Most of the customer pays through Electronic Payment and other payment methods are balanced.

# %% [markdown]
# Churn Barplot based on Customer Demographics

# %%
features = ["gender","Partner","Dependents"]
plt.figure(figsize = (10,8))
for i in range(0,len(features)):
    Churn_Customer = df.groupby(features[i],as_index = False)["Churn"].value_counts()
    plt.subplot(3, len(features)//2, i+1)
    ax = sns.barplot(x = features[i], palette = {"Yes": "Orange", "No": "Blue", "Male": "Orange", "Female": "Blue"}, y = "count", hue="Churn", data = Churn_Customer)
    ax.bar_label(ax.containers[0], color = "Black")
    ax.bar_label(ax.containers[1], color = "Black")
    plt.title("Churn By " + features[i])
    plt.ylabel("Number of Customers")
    plt.tight_layout()

# %% [raw]
# #1.It can be seen that Churn does not affect gender because the numbers for both male and female are almost same.
# #2.It can be seen that Churn is more in more in customers who does not a Partner.
# #3.It can be seen that Churn is more in more in customers who are not Dependents.

# %% [markdown]
# Churn Barplot based on Service Type

# %%
features = ["PhoneService","MultipleLines","InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies"]
plt.figure(figsize = (14,16))
for i in range(0,len(features)):
    Churn_Service = df.groupby(features[i],as_index = False)["Churn"].value_counts()
    plt.subplot(4, len(features)//3, i+1)
    ax = sns.barplot(x = features[i], palette = {"Yes": "Orange", "No": "Blue", "No phone service": "red", "DSL": "Red", "Fiber optic": "Orange", "No Internet": "Red"}, y = "count", hue="Churn", data = Churn_Service)
    ax.bar_label(ax.containers[0], color = "Black")
    ax.bar_label(ax.containers[1], color = "Black")
    plt.title("Churn By " + features[i])
    plt.ylabel("Number of Customers")
    plt.tight_layout()

# %% [raw]
# #1.For Churn on MultipleLines, it seems to be the same for customers who have multiplelines or not.
# #2.For Churn on InternetService, Fiber optic users Churned mostly than the others.
# #3.Customer who dont have / are provided OnlineSecurity, OnlineBackup, DeviceProtection and TechSupport churned Mostly.
# #4.Streaming Tv and Streaming Movies churn customers are almost same.

# %% [markdown]
# Churn Barplot based on Payment Type

# %%
features = ["Contract","PaperlessBilling","PaymentMethod"]
plt.figure(figsize = (12,6))
for i in range(0, len(features)):
    Churn_Payment = df.groupby(features[i],as_index = False)["Churn"].value_counts()
    plt.subplot(1, len(features), i+1)
    ax = sns.barplot(x = features[i], palette = {"Month-to-month": "Blue", "One year": "Orange", "Two year": "Green", "Yes": "Blue", "No": "Orange", "Electronic check": "Blue", "Mailed check": "Orange", "Bank transfer (automatic)": "Green", "Credit card (automatic)": "Red"}, y = "count", hue="Churn", data = Churn_Payment)
    ax.bar_label(ax.containers[0], color = "Black")
    ax.bar_label(ax.containers[1], color = "Black")
    plt.title("Chuen By " + features[i])
    plt.ylabel("Number of Customers")
    plt.xticks(rotation = 25)
    plt.tight_layout()

# %% [raw]
# #1.It can be seen that customer churn is dominant in payments made every month compared to other payments.
# #2.Customers who usually make payments through electronic payments with paperless bills churns most.

# %% [markdown]
# Scatterplot Churn by Tenure VS TotalCharges

# %%
sns.scatterplot(data = df, x = "tenure", y = "TotalCharges", hue = "Churn", style = "Churn")
plt.show()

# %% [raw]
# #It can be seen that longer tenure with higher TotalCharges has higher churn potential.

# %% [markdown]
# Scatterplot Churn By Tenure VS MonthlyCharges

# %%
sns.scatterplot(data = df, x = "tenure", y = "MonthlyCharges", hue = "Churn", style = "Churn")
plt.show()

# %% [raw]
# # It can be seen that Churn occurs mostly in tenure 0-20 months with large MonthlyCharges

# %% [markdown]
# Scatterplot Churn MonthlyCharges VS TotalCharges

# %%
sns.scatterplot(data = df, x = "MonthlyCharges", y = "TotalCharges", hue = "Churn", style = "Churn")
plt.show()

# %% [markdown]
# #Here we see more churn in Higher MonthlyCharges with lower TotalCharges
